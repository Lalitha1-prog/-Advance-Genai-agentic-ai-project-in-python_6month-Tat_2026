# %% [markdown]
# # List DataStructure

# %%
l=[]
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l.append(30)
l
# Out:
# [10, 20, 30, 40, 50, 30]

# %%
l1=[10,2.3,1+2j,True,'nit',[1,2,3]]
l1
# Out:
# [10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
len(l1)
# Out:
# 6

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 30]
# [10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 30]

# %%
l1
# Out:
# [10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
l2=l.copy()
l2
# Out:
# [10, 20, 30, 40, 50, 30]

# %%
print(id(l))
print(id(l1))
print(id(l2))
# Out:
# 2733420271296
# 2733467495936
# 2733420258496

# %%
l2
# Out:
# [10, 20, 30, 40, 50, 30]

# %%
len(l2)
# Out:
# 6

# %%
l2.clear()
l2
# Out:
# []

# %%
len(l2)
# Out:
# 0

# %%
l2
# Out:
# []

# %%
l
# Out:
# [10, 20, 30, 40, 50, 30]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 30]

# %%
l.count(10)
# Out:
# 1

# %%
l.count(100)
# Out:
# 0

# %%
print(l)
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 30]
# [10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]
# []

# %%
a=[1,2,3]
b=[4,5,6]
a.extend(b)
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l2.extend(l)
l2
# Out:
# [10, 20, 30, 40, 50, 30]

# %%
l2.extend(l1)
l2
# Out:
# [10, 20, 30, 40, 50, 30, 10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 30]
# [10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]
# [10, 20, 30, 40, 50, 30, 10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
l[0]
# Out:
# 10

# %%
l[0]=100

# %%
l
# Out:
# [100, 20, 30, 40, 50, 30]

# %%
job=[5000]
job
# Out:
# [5000]

# %%
job[0]
# Out:
# 5000

# %%
job[0]=1000
job
# Out:
# [1000]

# %%
l
# Out:
# [100, 20, 30, 40, 50, 30]

# %%
l2
# Out:
# [10, 20, 30, 40, 50, 30, 10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
l2.index(10)
# Out:
# 0

# %%
l
# Out:
# [100, 20, 30, 40, 50, 30]

# %%
l2.insert(3,35)
l2
# Out:
# [10, 20, 30, 35, 40, 50, 30, 10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
l2
# Out:
# [10, 20, 30, 35, 40, 50, 30, 10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
l2.pop()
# Out:
# [1, 2, 3]

# %%
l2
# Out:
# [10, 20, 30, 35, 40, 50, 30, 10, 2.3, (1+2j), True, 'nit']

# %%
l2.pop()
# Out:
# 'nit'

# %%
l2.pop()
# Out:
# True

# %%
l2
# Out:
# [10, 20, 30, 35, 40, 50, 30, 10, 2.3, (1+2j)]

# %%
l2.pop(2)
# Out:
# 30

# %%
l2
# Out:
# [10, 20, 35, 40, 50, 30, 10, 2.3, (1+2j)]

# %%
l2.pop(5)
# Out:
# 30

# %%
l
# Out:
# [100, 20, 30, 40, 50, 30]

# %%
l2.reverse()
l2
# Out:
# [(1+2j), 2.3, 10, 50, 40, 35, 20, 10]

# %%
l.sort()
l2
# Out:
# [(1+2j), 2.3, 10, 50, 40, 35, 20, 10]

# %%
l.sort(reverse=True)
l2
# Out:
# [(1+2j), 2.3, 10, 50, 40, 35, 20, 10]

# %%
l3=[10,20,[2,3],3]

# %%
l3[2]=[2]
l3
# Out:
# [10, 20, [2], 3]

# %%
l4=[30,40,[1,2],7]
l4
# Out:
# [30, 40, [1, 2], 7]

# %%
l4[2]=[2]
l4
# Out:
# [30, 40, [2], 7]

# %%
l5=[4,5,9]
l5
# Out:
# [4, 5, 9]

# %%
l5[2]=[6]
l5
# Out:
# [4, 5, [6]]

# %%
l5[1]=[2]
l5
# Out:
# [4, [2], [6]]

# %% [markdown]
# # Set operation

# %%
s7={1,2,3,4,5}
s8={4,5,6,7,8}
s9={8,9,10}

# %%
s7|s8
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s7={1,2,3,4,5}
s8={4,5,6,7,8}
s9={8,9,10}

# %%
s7.intersection(s8)
# Out:
# {4, 5}

# %%
s8&s9
# Out:
# {8}

# %%
s7.difference(s8)
# Out:
# {1, 2, 3}

# %%
s8-s9
# Out:
# {4, 5, 6, 7}

# %%
s7.symmetric_difference(s8)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
s7.symmetric_difference_update(s8)
s7
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
a={1,2,3,4,5,6,7,8,9}
b={3,4,5,6,7,8}
c={10,20,30,40}

# %%
a.issuperset(b)
# Out:
# True

# %%
b.issuperset(c)
# Out:
# False

# %%
a.isdisjoint(b)
# Out:
# False

# %%
a.isdisjoint(c)
# Out:
# True

# %% [markdown]
# # variable declaration in python
# - variable = value

# %%
nit = 1030
nit
# Out:
# 1030

# %%
nit1 = 10
nit1
# Out:
# 10

# %%
NIT = 10
NIT
# Out:
# 10

# %%
nit_ = 6
nit_
# Out:
# 6

# %%
_nit = 5
_nit
# Out:
# 5

# %%
import keyword
keyword. kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
true=7
true
# Out:
# 7

# %%
a=true
a
# Out:
# 7

# %%
false=4
false
# Out:
# 4

# %%
b=false
b
# Out:
# 4

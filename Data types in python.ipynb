# %% [markdown]
# # Python Datatypes

# %% [markdown]
# # Integer

# %%
i=10
i
# Out:
# 10

# %%
 type(i)
# Out:
# int

# %%
id(int)
# Out:
# 140735492971984

# %%
int=100
int
# Out:
# 100

# %%
type(int)
# Out:
# int

# %% [markdown]
#  # Float

# %%
float=10.0
float
# Out:
# 10.0

# %%
f=24
f
# Out:
# 24

# %%
type(f)
# Out:
# int

# %%
f=28.e1 # e0 = 1, e1 = 10.0, e2 = 100.0,  e3 = 1000.0
f
# Out:
# 280.0

# %%
f1=453.e2
f1
# Out:
# 45300.0

# %%
type(f1)
# Out:
# float

# %%
F2=500.E3
F2
# Out:
# 500000.0

# %% [markdown]
# # Boolen

# %%
True=1
True
# Out:
# 1

# %%
True+True
# Out:
# 2

# %%
True+ False
# Out:
# 1

# %%
False//True #Boolen division
# Out:
# 0

# %%
False/True
# Out:
# 0.0

# %%
True*True
# Out:
# 1

# %%
True*False
# Out:
# 0

# %%
b=True #True=1 and False=0
b1=False
c=b+b1
c
# Out:
# 1

# %%
type(c)
# Out:
# int

# %%
b=False
type(b)
# Out:
# bool

# %%
int(True)
# Out:
# 1

# %% [markdown]
# # Complex

# %%
c = 1+2j #1-real part @ 2j-imaginary part [art where j=square root of -1
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 1.0

# %%
c.imag
# Out:
# 2.0

# %%
c1=10+20j
print(c)
print(c1)
# Out:
# (1+2j)
# (10+20j)

# %%
c+c1
# Out:
# (11+22j)

# %% [markdown]
# # String

# %%
'welcome ' #it will work with single quotes
# Out:
# 'welcome'

# %%
"welcome to python" #it will work with double quotes
# Out:
# 'welcome to python'

# %%
'''welcome
to
python'''       #it will work with threeble quotes
# Out:
# 'welcome\nto\npython'

# %%
s='bharath'
s[3]
# Out:
# 'r'

# %%
s1='welcome'
s1
# Out:
# 'welcome'

# %%
len(s1)
# Out:
# 7

# %%
s1="welcome to biet"
s1[6]
# Out:
# 'e'

# %%
s='bharath'
s[-4]
# Out:
# 'r'

# %%
s[:] #print whool strings
# Out:
# 'welcome'

# %%
s[3:]
# Out:
# 'come'

# %%
s1[4:]
# Out:
# 'ome'

# %%
s1[:4]
# Out:
# 'welc'

# %%
s1[0:]
# Out:
# 'welcome'

# %%
s1[2:]
# Out:
# 'lcome'

# %%
s1
# Out:
# 'welcome'

# %%
s1[::1]
# Out:
# 'welcome'

# %%
s1[::2]
# Out:
# 'wloe'

# %%
s1[::3]
# Out:
# 'wce'

# %%
s1[::-2]
# Out:
# 'eolw'

# %%
s3='welcometeam'
s3
# Out:
# 'welcometeam'

# %%
s3[::-2]
# Out:
# 'meeolw'

# %%
s3[::3]
# Out:
# 'wcea'

# %% [markdown]
# # python type casting

# %% [markdown]
# # type cast to int data type

# %%
int(2.3)
# Out:
# 2

# %%
int(True)
# Out:
# 1

# %%
int('10')
# Out:
# 10

# %% [markdown]
# # other datatype to folat

# %%
float(20)
# Out:
# 20.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('20')
# Out:
# 20.0

# %% [markdown]
# # all other datatype to bool

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1+2j)
# Out:
# True

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool('zero')
# Out:
# True

# %% [markdown]
# # number system

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(30)
# Out:
# '0b11110'

# %%
int(0b11001)
# Out:
# 25

# %%
int(25)
# Out:
# 25

# %%
oct(25)
# Out:
# '0o31'

# %%
int(25)
# Out:
# 25

# %%
print(0xa)
print(0xb)
print(0xc)
print(0xd)
print(0xe)
print(0xf)
# Out:
# 10
# 11
# 12
# 13
# 14
# 15

# %%
0x19
# Out:
# 25

# %%
int(19)
# Out:
# 19

# %%
0x50
# Out:
# 80

# %%
0x25
# Out:
# 37

# %%
int(25)
# Out:
# 25

# %% [markdown]
# # Bit Wise operator(Complement~)

# %%
a=3
-a
# Out:
# -3

# %%
~3
# Out:
# -4

# %%
12&20
# Out:
# 4

# %%
12|13
# Out:
# 13

# %%
12^13
# Out:
# 1

# %%
print(bin(25))
print(bin(30))
# Out:
# 0b11001
# 0b11110

# %%
25^30
# Out:
# 7

# %%
12<<1
# Out:
# 12

# %%
12<<2
# Out:
# 48

# %%
12<<3
# Out:
# 96

# %%
25<<1
# Out:
# 50

# %%
#rignht shift >> we will loose the bit

# %%
12>>1
# Out:
# 6

# %%
13>>3
# Out:
# 1

# %%
25>>2
# Out:
# 6

# %%
name1 ="lalli"
name2 = "chinnu"
print(name1>name2)
# Out:
# True

# %%
name1 = "Alice" 
name2 = "Bob" 
print(name1 < name2)
# Out:
# True

# %% [markdown]
# # print()

# %%
num1=10
num2=20
add=num1+num2
print(add)
# Out:
# 30

# %%
num1=20
num2=30
add=num1+num2
print('the addition of{} and{} is={}'.format(num1,num2,add))
# Out:
# the addition of20 and30 is=50

# %%
num1=10
num2=30
add=num1+num2
print('the substraction of {} and{} is={}'.format(num1,num2,add))
# Out:
# the substraction of 10 and30 is=40

# %%
num2=40
num3=50
add=num2+num3
print(f'the addition of{num2} nad{num3} is={add}')
# Out:
# the addition of40 nad50 is=90

# %%
print("hello")
print("good morning")
# Out:
# hello
# good morning

# %%
print("hello",end='---')
print("good morning")
# Out:
# hello---good morning

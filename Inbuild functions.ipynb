# %% [markdown]
# # inbuild function

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
round(math.sqrt(25))
# Out:
# 5

# %%
x=round(math.sqrt(25))
x
# Out:
# 5

# %%
math.floor(3.4)
# Out:
# 3

# %%
math.ceil(4.5)
# Out:
# 5

# %%
pow(3,2)
# Out:
# 9

# %%
math.pi
# Out:
# 3.141592653589793

# %%
pi = 4.13
pi
# Out:
# 4.13

# %%
import math as a
a.sqrt(25)
# Out:
# 5.0

# %%
import math as m
m.sqrt(30)
# Out:
# 5.477225575051661

# %%
from math import sqrt,floor
print(floor(2.3))
print(m.sqrt(10))
# Out:
# 2
# 3.1622776601683795

# %%
print(math.e)
# Out:
# 2.718281828459045

# %% [markdown]
# # input()

# %%
input()
# Out:
#  hello
# 'hello'

# %%
input()
input()
# Out:
#  hello
#  hi
# 'hi'

# %%
X=input()
Y=input()
Z=X+Y
print(Z)
# Out:
#  3
#  2
# 32

# %%
print(type(X))
print(type(Y))
print(type(Z))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
X=int(input())
Y=int(input())
Z=X+Y
print(Z)
# Out:
#  3
#  2
# 5

# %%
print(type(X))
print(type(Y))
print(type(Z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x1=input('enter the 1st number')
y1=input('enter the 2nd number')
z1=x1+y1
print(z1)
# Out:
# enter the 1st number 10
# enter the 2nd number 20
# 1020

# %%
x1=int(input())
y1=int(input())
z1=x1+y1
print(z1)
# Out:
#  10
#  20
# 30

# %%
x2=input('enter user_name:')
y2=input('enter password:')
z2=x2+y2
print(z2)
# Out:
# enter user_name: lalitha
# enter password: chinnu
# lalithachinnu

# %%
st=input('enter a string')
print(st)
# Out:
# enter a string hello
# hello

# %%
st=input('enter a string')[0]
print(st)
# Out:
# enter a string biet
# b

# %%
st=input('enter a string')[
print(st)

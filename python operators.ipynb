# %% [markdown]
# # python operators

# %% [markdown]
# # arithmatic operator

# %%
x1,y1=10,5 #arithmetic operator

# %%
x1+y1
# Out:
# 15

# %%
x1-y1
# Out:
# 5

# %%
x1*y1
# Out:
# 50

# %%
x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1**y1
# Out:
# 100000

# %%
x1%y1
# Out:
# 0

# %%
4**2
# Out:
# 16

# %% [markdown]
# # Assingnement operator

# %%
x=2 #assingnement operator

# %%
x=x+2
x
# Out:
# 4

# %%
x+=2
x
# Out:
# 8

# %%
x-=2
x
# Out:
# 6

# %%
x*=2
x
# Out:
# 12

# %%
x/=2
x
# Out:
# 6.0

# %%
x//=2
x
# Out:
# 3.0

# %% [markdown]
# # unary operator

# %%
n=7 #unary operator
n
# Out:
# 7

# %%
-n
# Out:
# -7

# %%
m=-n
m
# Out:
# -7

# %% [markdown]
# # Relational operator

# %%
a=5 #relational operator
b=6

# %%
a<b
# Out:
# True

# %%
b<a
# Out:
# False

# %%
a=b

# %%
a==b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
a!=b
# Out:
# False

# %% [markdown]
# # logical oprator

# %%
a=5 #logical operator
b=4

# %%
a<b and b<a
# Out:
# False

# %%
a<8 and b<5
# Out:
# True

# %%
a>3 and b>2
# Out:
# True

# %%
a>4 or b>6
# Out:
# True

# %%
a<6 or b<3
# Out:
# True

# %%
a<2 or b<5
# Out:
# True

# %%
a<6 or b>7
# Out:
# True

# %%
not x
# Out:
# False

# %%
-True
# Out:
# -1

# %%
-False
# Out:
# 0

# %%
10+3*2-1
# Out:
# 15

# %%
10+3*(2-1)
# Out:
# 13

# %%
print(10)
print(20)
print('welcome')
print(10,20,'welcome')
# Out:
# 10
# 20
# welcome
# 10 20 welcome
